# %% [markdown]
# <a href="https://colab.research.google.com/github/ashu0703/Hotel_Booking_Analysis/blob/main/Hotel_Booking_Analysis_Capstone_Project_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# # **Data Description:**
# **hotel** : 1)Resort Hotel 2)City Hotel).
#
# **is_canceled** :if the booking was canceled (1) or not canceled (0)
#
# **lead_time**:Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
#
#  **arrival_date_year** : arriving Year date
#
# **arrival_date_month**: arriving Month date
#
# **arrival_date_week_number** : Week number in year for arrival date
#
# **arrival_date_day_of_month** : Day of arrival date
#
# **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday)
#
# **stays_in_week_nights** : Number of stay in  week nights i.e Monday to Friday
#
# **adults** : Number of adults
#
# **children** : Number of children
#
# **babies**: Number of babies
#
# **meal**: Type of meal preferred.
#
#   Undefined/SC – no meal package
#
#   BB – Bed & Breakfast
#
#   HB – Half board (breakfast and one other meal)
#
#   FB – Full board (breakfast, lunch and dinner)
#
# **country** : Country of origin
#
# **market_segment** : Market segment designation.
#
# TA:- Travel Agents and TO:-Tour Operators
#
# **distribution_channel**: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# **is_repeated_guest** : The booking name was from a repeated guest (1) or not (0)
#
# **previous_cancellations** : Number of previous bookings that were cancelled by the customer compare to the current booking
#
# **previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer compare to the current booking
#
# **reserved_room_type** : Code of room type reserved.
#
# **assigned_room_type** : Code for the type of room assigned to the booking.
#
# **booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# **deposit_type**: customer made a deposit to guarantee the booking. This variable can assume three categories:
#
# No Deposit – no deposit was made
#
# Non Refund - a deposit was made in the value of the total stay
#
# cost Refundable – a deposit was made with a value under the total cost of stay.
#
# **agent** : ID of the travel agency that made the booking
#
# **company** : ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
#
# **days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# **customer_type** : Type of booking, assuming one of four categories:
#
# Contract - when the booking has an allotment or other type of contract associated to it
#
# Group– when the booking is associated to a group
#
# Transient– when the booking is not part of a group or contract, and is not associated to other transient booking
#
# Transient-party – when the booking is transient, but is associated to at least other transient booking
#
# **adr**: It is measured as the total revenues generated by all the occupied rooms in a hotel or lodge divided by the total number of occupied rooms over a given time period. It is a simple average that shows the revenues generated per occupied room.
#
# The average daily rate (ADR) is a useful tool to maximize revenues in the hospitality sector. The ADR is measured as the total revenues generated by all the occupied rooms in the hotel or lodge divided by the total number of occupied rooms over a given time period. The average daily rate includes only the occupied rooms and not the total available stock. List item
#
# **required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# **total_of_special_requests **: Number of special requests made by the customer
#
# **reservation_status** : Reservation last status, assuming one of three categories:
#
# Check-Out– customer has checked in but already departed
#
# No-Show – customer did not check-in and did inform the hotel of the reason
#
#
#  **reservation_status_date** : Date at which the last status was set.

# %% [markdown]
# # **Importing Library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Hotel Bookings.csv')

# %%
# now creating a duplicated copy of data set so that futher manipulation in dataset will not affect origional dataset and we can use for refrence further.
df=data.copy()

# %% [markdown]
# # **Data Inspection**

# %%
# shape of both dataset origional and duplicate copy
df.shape, data.shape
# Out:
# ((119390, 32), (119390, 32))

# %% [markdown]
# **Top 4 row**

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# bottom 5 row

df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# column of data
#all columns in dataset display here 

df.columns.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
# statistical information about numrical variables in dataset.

df.describe(exclude='object').round(2)
# Out:
#        is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# count    119390.00  119390.00          119390.00                 119390.00
# mean          0.37     104.01            2016.16                     27.17
# std           0.48     106.86               0.71                     13.61
# min           0.00       0.00            2015.00                      1.00
# 25%           0.00      18.00            2016.00                     16.00
# 50%           0.00      69.00            2016.00                     28.00
# 75%           1.00     160.00            2017.00                     38.00
# max           1.00     737.00            2017.00                     53.00
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                  119390.00                119390.00
# mean                       15.80                     0.93
# std                         8.78                     1.00
# ...

# %%
# Transpose of all columns

df.describe(exclude='object').round(2).T
# Out:
#                                    count     mean     std      min      25%  \
# is_canceled                     119390.0     0.37    0.48     0.00     0.00
# lead_time                       119390.0   104.01  106.86     0.00    18.00
# arrival_date_year               119390.0  2016.16    0.71  2015.00  2016.00
# arrival_date_week_number        119390.0    27.17   13.61     1.00    16.00
# arrival_date_day_of_month       119390.0    15.80    8.78     1.00     8.00
# stays_in_weekend_nights         119390.0     0.93    1.00     0.00     0.00
# stays_in_week_nights            119390.0     2.50    1.91     0.00     1.00
# adults                          119390.0     1.86    0.58     0.00     2.00
# children                        119386.0     0.10    0.40     0.00     0.00
# babies                          119390.0     0.01    0.10     0.00     0.00
# is_repeated_guest               119390.0     0.03    0.18     0.00     0.00
# ...

# %%
# statistical information about Object variables in dataset.

df.describe(include='object').T
# Out:
#                           count unique         top    freq
# hotel                    119390      2  City Hotel   79330
# arrival_date_month       119390     12      August   13877
# meal                     119390      5          BB   92310
# country                  118902    177         PRT   48590
# market_segment           119390      8   Online TA   56477
# distribution_channel     119390      5       TA/TO   97870
# reserved_room_type       119390     10           A   85994
# assigned_room_type       119390     12           A   74053
# deposit_type             119390      3  No Deposit  104641
# customer_type            119390      4   Transient   89613
# reservation_status       119390      3   Check-Out   75166
# reservation_status_date  119390    926  2015-10-21    1461

# %%
# checking null/missing values.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # **Handeling Null Value**

# %%
# we are checking here some wrong entries like #,@,%,?,+,& in string or in integer type coloumn that we are unable to find during null value detection. 
for num,col in enumerate(df.columns,1):
    print('\n')
    print(num,')\n','{} : {}'.format(col,df[col].unique().tolist()))
# Out:
# 1 )
#  hotel : ['Resort Hotel', 'City Hotel']
#
#
# 2 )
#  is_canceled : [0, 1]
#
#
# 3 )
# ...

# %%
# Finding Null Values and arrange in decending orders

null_val = df.isnull().sum().sort_values(ascending=False).head().reset_index().rename(columns={'index':'country',0:'count'})
null_val
# Out:
#               country   count
# 0             company  112593
# 1               agent   16340
# 2             country     488
# 3            children       4
# 4  reserved_room_type       0

# %%
# percentage of null value 

percentage_of_null_value = ((df.isnull().mean())*100).sort_values(ascending=False).head().reset_index().rename(columns={'index':'country',0:'%age'})
percentage_of_null_value
# Out:
#               country       %age
# 0             company  94.306893
# 1               agent  13.686238
# 2             country   0.408744
# 3            children   0.003350
# 4  reserved_room_type   0.000000

# %%
# Heatmap to see null values in dataset

plt.figure(figsize=(20,8))
sns.heatmap(df.isnull(),cbar=False,cmap='icefire')
plt.title('Missing values display',fontsize=20)
plt.show()

# %%
# Filling null values
# In children null value filling with 0.
# Agent column fill with 0.
# Country  column fill with 'others'

df['children'].fillna(0,inplace=True)
df['agent'].fillna(0,inplace=True)
df['country'].fillna('others',inplace=True)

# Dropping company column as it contains maximum of null values.

df.drop(['company'],axis=1,inplace=True)

# %%
 # As children and agent present in float datatype, which is not possible.so converting it into integer. 

df['children']=df['children'].astype(int)
df['agent']=df['agent'].astype(int)

# %%
# creating a new column.

# 1) merging adult, childrens, babies column to a 'total people' 
df['total_people'] = df['adults']+df['babies']+df['children']

# 2) merging 'stays_in_week_nights'

df['total_stay']= df['stays_in_week_nights']+df['stays_in_weekend_nights']

# %% [markdown]
# **Updated column**

# %%
df.columns.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date',
#  'total_people',
#  'total_stay']

# %%
# Re-check any null value still present.

df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # **Handling Duplicate values**

# %%
# checking duplicate value.

df.duplicated().value_counts()
# Out:
# False    87389
# True     32001
# dtype: int64

# %%
# Droping the dulpicate values from dataset

df.drop_duplicates(inplace=True)

# Re-check the duplicates if any present after droping the duplicates from data sets.

df.duplicated().value_counts()
# Out:
# False    87389
# dtype: int64

# %% [markdown]
# # **Outlier Detection**

# %%
# outlier detection from numerical column

num_column=['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children','required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']
n = 1
plt.figure(figsize=(20,15))
for column in num_column :
  plt.subplot(9,3,n)
  n = n+1
  sns.boxplot(df[column])
  plt.tight_layout()

# %%
# Removing Outlier
df.loc[df.lead_time > 500, 'lead_time'] = 500
df.loc[df.stays_in_weekend_nights >=  5, 'stays_in_weekend_nights'] = 5
df.loc[df.adults > 4, 'adults'] = 4
df.loc[df.previous_bookings_not_canceled > 0, 'previous_bookings_not_canceled'] = 1
df.loc[df.previous_cancellations > 0, 'previous_cancellations'] = 1
df.loc[df.stays_in_week_nights > 10, 'stays_in_week_nights'] = 10
df.loc[df.booking_changes > 5, 'booking_changes'] = 5
df.loc[df.required_car_parking_spaces > 5, 'required_car_parking_spaces'] = 0
df.loc[df.children > 8, 'children'] = 0
df.loc[df.adr > 1000, 'adr'] = 1000

# %%
# Re-check outlier confromation 
num_column1= ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children','required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes']
n = 1
plt.figure(figsize=(20,15))
for column in num_column1:
  plt.subplot(9,2,n)
  n = n+1
  sns.boxplot(df[column])
  plt.tight_layout()

# %% [markdown]
# # **Univariate Analysis**

# %% [markdown]
# ### **Most Preferred Hotel Type**

# %%
Preferred_by_customer=df['hotel'].value_counts()
Preferred_by_customer
# Out:
# City Hotel      53426
# Resort Hotel    33963
# Name: hotel, dtype: int64

# %%
# Hotel Preferred by customer

fig = plt.figure(figsize=(15,6))

Preferred_by_customer.plot(kind='pie', colors=['orangered', 'blue'], autopct='%1.1f%%',startangle =90, textprops={'fontsize': 14},explode = (0, 0.1),shadow=True)
plt.title('Most preferred Hotel',fontsize=15,fontweight="bold")
plt.ylabel('')

fig.patch.set_facecolor('#95a3a6')

plt.show()

# %% [markdown]
# Most demanded Hotel type is City hotel type here we can see that 61% guset prefered to city hotel and 38% guest prefered Resort Hotel

# %% [markdown]
# ### **cancellation and non cancellation**

# %%
# cancelation and non-cancellation

canc_no_canc=df.copy()
canc_no_canc['is_canceled'] = canc_no_canc['is_canceled'].replace([1,0], ['canceled', 'not_canceled'])

canc_no_canc=canc_no_canc.groupby('is_canceled')['is_canceled'].count()
canc_no_canc
# Out:
# is_canceled
# canceled        24025
# not_canceled    63364
# Name: is_canceled, dtype: int64

# %%
# Cancellation and Non-Cancellation
fig = plt.figure(figsize=(10,5))

canc_no_canc.plot(kind='pie',startangle=280, pctdistance=0.85, explode = (0, 0.1),autopct='%1.1f%%')
plt.title('cancellation and non cancellation',fontsize=15,fontweight='bold')
plt.ylabel('')

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle) 


fig.patch.set_facecolor('#95a3a6')

plt.show()

# %% [markdown]
# we can observe that 72% guest are satisfied with their booking and not canceling theirs booking

# %% [markdown]
# ### **Repeated & Non Repeated guest**

# %%
rep_no_rep_guest=df.copy()
rep_no_rep_guest['is_repeated_guest']=rep_no_rep_guest['is_repeated_guest'].replace([1,0], ['Repeated', 'Not-Repeated'])
rep_no_rep_guest=rep_no_rep_guest.groupby('is_repeated_guest')['is_repeated_guest'].count()
rep_no_rep_guest
# Out:
# is_repeated_guest
# Not-Repeated    83974
# Repeated         3415
# Name: is_repeated_guest, dtype: int64

# %%
fig=plt.figure(figsize=(10,5)) 

rep_no_rep_guest.plot(kind='pie',autopct = '%.0f%%',explode = (0,0.1),shadow=True,colors=['mediumpurple','cyan'])
plt.title('Repeated & Non Repeated guest',fontsize=15,fontweight='bold')
plt.ylabel('')


fig.patch.set_facecolor('bisque')

plt.show()

# %% [markdown]
# less number of person are repeating to same hotel or same hotel type

# %% [markdown]
# ### **Which agent did highest booking**

# %%
#highest bookings
highest_bookings=df.groupby('agent')['agent'].count().sort_values(ascending=False).head(20)
highest_bookings
highest_bookings=pd.DataFrame(highest_bookings).rename(columns={'index':'agent','agent':'no of booking counts'})
highest_bookings
highest_bookings.drop(index=[0], inplace=True)

highest_bookings
# Out:
#        no of booking counts
# agent
# 9                     28757
# 240                   13027
# 14                     3349
# 7                      3300
# 250                    2779
# 241                    1644
# 28                     1502
# 8                      1383
# 1                      1232
# 6                      1117
# 40                      986
# 314                     844
# 242                     722
# 83                      614
# 85                      524
# 243                     477
# 171                     402
# 27                      395
# 3                       363

# %%
# Here 1,2,3,4,5,6 are token / code name given to every agent 

highest_bookings.plot(kind="bar",)
plt.title('Agent',fontweight="bold",fontsize=15)
plt.xlabel('Distribution_channel',size=15)


ax = plt.gca()
ax.patch.set_facecolor('#e6daa6')

plt.show()

# %% [markdown]
# Here the Agent-ID number is given to every agents.So in all agent ID number 9 agent did highest bookings

# %% [markdown]
# # **Hotel Wise Analysis**

# %% [markdown]
# Most booking by which segment and distribution **channel**

# %%
#segment wise

preferred_segmnet=df.groupby('market_segment')['market_segment'].count()
preferred_segmnet

# distribution wise

distribution_wise=df.groupby('distribution_channel')['distribution_channel'].count()
distribution_wise

print(preferred_segmnet,'\n\n',distribution_wise)
# Out:
# market_segment
# Aviation           227
# Complementary      702
# Corporate         4208
# Direct           11804
# Groups            4942
# Offline TA/TO    13889
# Online TA        51615
# Undefined            2
# Name: market_segment, dtype: int64
#
#  distribution_channel
# Corporate     5077
# Direct       12988
# GDS            181
# TA/TO        69138
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
# segment and distribution channel

fig=plt.figure(figsize=(25,5))
plt.subplot(1, 2, 1)
sns.countplot(x='market_segment', data=df, palette="Set2")
plt.title('Types of market segment',fontweight="bold", fontsize=20)
plt.xlabel('market_segment',size=15)

fig.patch.set_facecolor('silver')
ax = plt.gca()
ax.patch.set_facecolor('#fffcc4')

plt.subplot(1, 2, 2)
sns.countplot(x='distribution_channel', data=df, palette='rocket')
plt.title('Distribution_channel',fontweight="bold", fontsize=15)
plt.xlabel('distribution_channel',size=15)

fig.patch.set_facecolor('silver')
ax = plt.gca()
ax.patch.set_facecolor('#fffcc4')

plt.show()

# %% [markdown]
# We can see that in distribution channel TA/TO having highest booking i.e Tour Agent and Tour Operators same we can see that in market segment also online tour Agent did more booking  compare to others

# %% [markdown]
# **Reserved room type and Assigned room type**

# %%
# Reserved Room type code

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(25,5))
sns.countplot( x=df['reserved_room_type'],hue=df['hotel'],ax=ax1)
ax1.title.set_text('reserved_room_type')

fig.patch.set_facecolor('cadetblue')
ax1 = plt.gca()
ax1.patch.set_facecolor('snow')

# Assigned Room type code

sns.countplot(x=df['assigned_room_type'],hue=df['hotel'] ,ax=ax2 )
ax2.title.set_text('assigned_room_type')

fig.patch.set_facecolor('silver')
ax2 = plt.gca()
ax2.patch.set_facecolor('snow')

plt.show()

# %% [markdown]
# Here we can cleary see that the demand of A room type is more may be this room having low cost and beacuse of this guest demand this type of affordable Rooms
#
# we can see that the booking for A type room is 37000 approx and assigned room to the guest is approx 3000 less

# %% [markdown]
# **Number of times booking changes done by customers.**

# %%
booking_changes=df[(df['booking_changes']!=0) & (df['booking_changes']< 10)]
booking_changes=booking_changes[['hotel','booking_changes']]
booking_changes
# Out:
#                hotel  booking_changes
# 0       Resort Hotel                3
# 1       Resort Hotel                4
# 13      Resort Hotel                1
# 21      Resort Hotel                1
# 23      Resort Hotel                1
# ...              ...              ...
# 119355    City Hotel                1
# 119356    City Hotel                3
# 119359    City Hotel                1
# 119362    City Hotel                2
# 119371    City Hotel                1
#
# [15902 rows x 2 columns]

# %%
fig=plt.figure(figsize = (10,5))

sns.countplot(x='booking_changes',hue='hotel',data=booking_changes)
plt.title("Booking changes by customers ",fontsize=20, fontweight='bold')
plt.xlabel("booking_changes", fontsize=14 )
plt.ylabel("count",fontsize=14 )

fig.patch.set_facecolor('silver')
ax = plt.gca()
ax.patch.set_facecolor('#fffcc4')

plt.show()

# %% [markdown]
# Booking changes by the customers not more 1 or 2 times only customers and this as due to more waiting time or change in assigned room type at the time of check in

# %% [markdown]
# **Optimal Length stay of Hotel**

# %%
fig=plt.figure(figsize=(15,5))

not_canceled=df.copy()
not_canceled=not_canceled[not_canceled['is_canceled']==0]
optimal_stay_length= not_canceled[not_canceled['total_stay'] < 15]

sns.kdeplot(x =optimal_stay_length['total_stay'], hue = optimal_stay_length['hotel'])
plt.title('Optimal length of stay',fontsize=20,fontweight='bold')
plt.xlabel("total_stay'", fontsize=15 )
plt.ylabel(' ')

fig.patch.set_facecolor('silver')
ax = plt.gca()
ax.patch.set_facecolor('#fffcc4')

plt.show()

# %% [markdown]
# Average length to saty in both hotel is almost same in the range 1-5 days in city hotel stay number count is more compare to resort hotel

# %% [markdown]
# # **Cancellation**

# %% [markdown]
# **Cancellation month**

# %%
# 1)cancellation hotel wise
cancelation=df.copy()
cancelation1=cancelation[cancelation['is_canceled']==1]
sns.countplot(x='hotel',hue='is_canceled',data=cancelation1)
plt.show()

# %%
# 2) cancellation month wise
mothly_cancelation=df.copy()
mothly_cancelation1=mothly_cancelation[mothly_cancelation['is_canceled']==1]   
mothly_cancelation1

fig=plt.figure(figsize=(15, 5))

sns.countplot(x='arrival_date_month', hue = 'hotel' , data = mothly_cancelation1)
plt.title('month wise cancellation',fontsize=20,fontweight='bold')
plt.xlabel('month', fontsize=15 )
plt.ylabel("count",fontsize=15 )

fig.patch.set_facecolor('slategrey')
ax = plt.gca()
ax.patch.set_facecolor('beige')

plt.show()

# %% [markdown]
# As we have seen that number of booking is more in may to august month same Proportionality we can see in cancelling of hotel bookings  and the cancellation done more in City type hotel

# %% [markdown]
# **cancellation with deposit type**

# %%
fig=plt.figure(figsize=(10, 5))

sns.countplot(hue='is_canceled',x='deposit_type',data=df)
plt.title('cancellation with deposit type',fontsize=20,fontweight='bold')
plt.xlabel('Deposit type', fontsize=15 )
plt.ylabel("count",fontsize=15 )

fig.patch.set_facecolor('lightseagreen')
ax = plt.gca()
ax.patch.set_facecolor('lightcyan')

plt.show()

# %% [markdown]
# Most of the booking prefered by the customers is no deposit as the don't want any risk and refundable and non refund booking type is minimal

# %% [markdown]
# **Cancellation done due to Waiting list and Lead time**

# %%
waiting_list=df.copy()
waiting_list=waiting_list[waiting_list['days_in_waiting_list']>0]

fig=plt.figure(figsize=(10, 5))
sns.histplot(x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_list)
plt.title('cancellation done with waiting list',fontsize=20,fontweight='bold')
plt.xlabel('Waiting list', fontsize=15 )
plt.ylabel("count",fontsize=15 )

fig.patch.set_facecolor('lightseagreen')
ax = plt.gca()
ax.patch.set_facecolor('lightcyan')

plt.show()

# %%
fig=plt.figure(figsize=(10, 5))

sns.kdeplot(x = 'lead_time', hue = 'is_canceled' , data =df)
plt.title('cancellation done with lead time',fontsize=20,fontweight='bold')
plt.xlabel('lead time', fontsize=15 )
plt.ylabel("count",fontsize=15)

fig.patch.set_facecolor('lightseagreen')
ax = plt.gca()
ax.patch.set_facecolor('lightcyan')

plt.show()

# %% [markdown]
# we can see that with the increase in the Waiting time & lead time cancelation of hotel booking is done and the lead time range 1-50 in which cancellation is more, same with waiting time also

# %% [markdown]
# **Cancellation due to assigned room type**

# %%
fig=plt.figure(figsize=(10, 5))

sns.histplot(x = 'assigned_room_type', hue = 'is_canceled' , data =df)
plt.title('cancellation done due to assign room type',fontsize=20,fontweight='bold')
plt.xlabel('Assign room type', fontsize=15 )
plt.ylabel("count",fontsize=15)

fig.patch.set_facecolor('lightseagreen')
ax = plt.gca()
ax.patch.set_facecolor('lightcyan')

plt.show()

# %% [markdown]
# Here we can see that no of demand in booking a room in hotel is Type- A but at the time of arrivals due to high demand rooms not available and room assigned to customers is changed

# %% [markdown]
# # **ADR**

# %% [markdown]
# Average ADR in a **hotel**

# %%
avg_adr1=df.copy()
avg_adr1=avg_adr1[avg_adr1['is_canceled']==0]
avg_adr1=avg_adr1.groupby(['hotel'])
avg_adr1=avg_adr1['adr'].median().reset_index().rename(columns = {'adr':'avg_adr'}).round(2)
avg_adr1
# Out:
#           hotel  avg_adr
# 0    City Hotel   102.00
# 1  Resort Hotel    74.25

# %%
fig=plt.figure(figsize=(8, 5))

sns.barplot(x = avg_adr1['hotel'], y =avg_adr1['avg_adr'] )
plt.title('Average ADR in a hotel',fontsize=20,fontweight='bold')
plt.xlabel('hotel', fontsize=15 )
plt.ylabel("count",fontsize=15)

fig.patch.set_facecolor('slategrey')
ax = plt.gca()
ax.patch.set_facecolor('lavender')

plt.show()

# %% [markdown]
# **month wise average ADR & average hotel fees per person**

# %%
#Avergae Adr Month wise

avg_adr2=df.copy()

avg_adr2=avg_adr2[avg_adr2['is_canceled']==0]
avg_adr2=avg_adr2.groupby(['hotel','arrival_date_month','arrival_date_year'])
avg_adr2=avg_adr2['adr'].median().reset_index().rename(columns = {'adr':'avg_adr'}).round(2)
avg_adr2
# Out:
#            hotel arrival_date_month  arrival_date_year  avg_adr
# 0     City Hotel              April               2016    96.30
# 1     City Hotel              April               2017   120.00
# 2     City Hotel             August               2015    81.00
# 3     City Hotel             August               2016   119.00
# 4     City Hotel             August               2017   134.00
# 5     City Hotel           December               2015    75.00
# 6     City Hotel           December               2016    88.40
# 7     City Hotel           February               2016    80.30
# 8     City Hotel           February               2017    88.20
# 9     City Hotel            January               2016    77.00
# 10    City Hotel            January               2017    87.60
# 11    City Hotel               July               2015    62.00
# 12    City Hotel               July               2016   110.46
# 13    City Hotel               July               2017   121.50
# ...

# %%
 # Average ADR per person
avg_rent_pp=df.copy()
avg_rent_pp=avg_rent_pp[avg_rent_pp['is_canceled']==0]
avg_rent_pp['adr_per_person'] = df['adr']/(df['adults'] + df['children'])

resort_mean = avg_rent_pp.loc[(avg_rent_pp.is_canceled ==0 ) & (avg_rent_pp.hotel == 'Resort Hotel'), 'adr_per_person'].median()
city_mean = avg_rent_pp.loc[(avg_rent_pp.is_canceled == 0) & (avg_rent_pp.hotel == 'City Hotel'), 'adr_per_person'].median()

print("The median price of Resort hotel is{:.2f}".format(resort_mean))
print ("The median price of city hotel is {:.2f}".format(city_mean))
# Out:
# The median price of Resort hotel is41.11
# The median price of city hotel is 53.55

# %%
fig=plt.figure(figsize=(27, 8))

# Avergae Adr Month wise
plt.subplot(1,2,1)
sns.lineplot(data=avg_adr2,x='arrival_date_month', y='avg_adr',hue='hotel')
plt.title('Average ADR month wise ',fontsize=20,fontweight='bold')
plt.xlabel('month', fontsize=15 )
plt.ylabel("average ADR",fontsize=15)

fig.patch.set_facecolor('slategrey')
ax = plt.gca()
ax.patch.set_facecolor('lavender')



# Average ADR per person
plt.subplot(1,2,2)

sns.lineplot(x= avg_rent_pp['arrival_date_month'], y= avg_rent_pp['adr_per_person'], hue= avg_rent_pp['hotel'])
plt.title('Average ADR per person ',fontsize=20,fontweight='bold')
plt.xlabel('month', fontsize=15 )
plt.ylabel("average ADR",fontsize=15)

fig.patch.set_facecolor('slategrey')
ax = plt.gca()
ax.patch.set_facecolor('lavender')

plt.show()

# %% [markdown]
# Average ADR is highest in month august and lowest in novenmber to january and average ADR per person is highest in august  in resort hotel and in city hotel may month

# %% [markdown]
# **How lead time affect the ADR**

# %%
adr_df=df[df["adr"]<=1000]
sns.jointplot(x="lead_time", y="adr", data=adr_df, s = 15,color='c')
plt.show()

# %% [markdown]
# The joint plot shows that increased lead time is associated with lower ADR, this would suggest that people who book far in advance enjoy lower costs for Hotels as compared to shorter bookings.

# %% [markdown]
# ##**Special request, Meal type, car parking**

# %% [markdown]
# **Demand of special request and meal type preferred by customers**

# %%
# special request done by customers

most_special_request=df.groupby('total_of_special_requests')['total_of_special_requests'].count().sort_values(ascending=False)
special_req=most_special_request.copy()
#special_req.drop(index=[0],inplace=True)
special_req=pd.DataFrame(special_req).rename(columns={'total_of_special_requests':'count of request'})

special_req
# Out:
#                            count of request
# total_of_special_requests
# 0                                     43889
# 1                                     29016
# 2                                     11811
# 3                                      2317
# 4                                       320
# 5                                        36

# %%
# Meal type preferred by customers
meal_prefered=df.groupby('meal')['meal'].count()

meal_prefered
# Out:
# meal
# BB           67971
# FB             360
# HB            9085
# SC            9481
# Undefined      492
# Name: meal, dtype: int64

# %%
 # subplot of special request and meal type done by customers.
fig = plt.figure(figsize=(15,5)) 

# For special request.
plt.subplot(1,2,1)

sns.lineplot(data=special_req,x='total_of_special_requests',y='count of request')
plt.title("Demand of Special Request ",fontsize=20,fontweight='bold')
plt.xlabel("special request", fontsize=15)
plt.ylabel("Total count of request",fontsize=15)

#for background colour
fig.patch.set_facecolor('tan')
ax = plt.gca()
ax.patch.set_facecolor('beige')

plt.grid(axis='y')



# For meal 
plt.subplot(1,2,2)

sns.countplot(data=df,x='meal')
plt.title('most meal prefered',fontsize=20,fontweight='bold')
plt.xlabel("Meal", fontsize=15)
plt.ylabel("count",fontsize=15)

#for background colour
fig.patch.set_facecolor('tan')
ax = plt.gca()
ax.patch.set_facecolor('beige')

plt.show()

# %% [markdown]
# The special request demand by most of the customers are 1 and 2 least demand were 3,4,5 might be resorts not having such facility or such type of request cost is more thst why customers not demand
#
# Highest number of demand for BB type (Bed & BreakFast)

# %% [markdown]
# **which hotel recived special request monthly**

# %%
sp_month=df.copy()
sp_month=sp_month[sp_month['is_canceled']==0]
sp_month=sp_month.groupby(['arrival_date_month','hotel'])['total_of_special_requests'].sum().reset_index()

sp_month
# Out:
#    arrival_date_month         hotel  total_of_special_requests
# 0               April    City Hotel                       2764
# 1               April  Resort Hotel                       1282
# 2              August    City Hotel                       4045
# 3              August  Resort Hotel                       3258
# 4            December    City Hotel                       1591
# 5            December  Resort Hotel                       1217
# 6            February    City Hotel                       1867
# 7            February  Resort Hotel                       1284
# 8             January    City Hotel                       1361
# 9             January  Resort Hotel                        998
# 10               July    City Hotel                       3427
# 11               July  Resort Hotel                       2537
# 12               June    City Hotel                       2807
# 13               June  Resort Hotel                       1402
# ...

# %%
fig=plt.figure(figsize=(15,5))

sns.lineplot(x='arrival_date_month', y='total_of_special_requests',hue='hotel', data=sp_month)
plt.title("special request demand Month wise",fontsize=20,fontweight='bold')
plt.xlabel("special request", fontsize=15)
plt.ylabel("Total count of request",fontsize=15)

fig.patch.set_facecolor('#85a3b2')
ax = plt.gca()
ax.patch.set_facecolor('#ffff81')

plt.show()

# %% [markdown]
# Special request we can see more in month august and july as this was the peak seasons so customers demand also most during this months

# %% [markdown]
# ### **Required car parking spaces**

# %%
fig = plt.figure(figsize=(10,5)) 

sns.countplot(x='required_car_parking_spaces', data =df,hue='hotel')
plt.title('Demand of car paking spaces in  hotel type',fontsize=20,fontweight='bold')
plt.xlabel('required_car_parking',fontsize=15)
plt.ylabel('count',fontsize=15)


#for background colour
fig.patch.set_facecolor('#95a3a6')
ax = plt.gca()
ax.patch.set_facecolor('#fffcc4')

plt.show()

# %% [markdown]
# Demand of car is less in both Hotels

# %% [markdown]
# ## **Conclusion:-**
#
# * Guest preferring Hotel:-
#
#   1)City hotel Demand:-61%
#
#   2)Resort Hotel:-38% guest
#
# * Repeating guest are less in numbers, various reason for this guest not   satisfied with hospitality, during booking time rooms was different and at the time of check-in assign rooms is different, higher waiting time etc. These may have some reasons that repeatation of customer is not more.
#
# * The demand of A room type is more may be Because of A room having low cost and beacuse of this demand of this in guest is more.
#
# * Distribution channel TA/TO having highest booking i.e Tour Agent and Tour Operators same we can see that in market segment also online tour Agent did more booking  compare to others so Hotel industry should
#
# * Average Lead time and waiting time more in city type hotel so city hotel due to may be high demand so make it guest comfortable city hotel should pre-planned so that customer due to this no cancel the bookings.
#
# * Average ADR is highest in month august and lowest in November to January and average ADR per person is highest in august month  in resort hotel and in city hotel may month
#
# * Hotel industry should offer such schemes in their off-seasons, so that  hotel industry expense recover from that scheme and so that in their peak time they generate profit
